# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import csv in colab as DataFrame (df) (Check pd.read_csv())

df = pd.read_csv("/content/drive/MyDrive/Self Learning /tesla.csv")

# %%
#Preview top 5 rows of df  (Check df.head())
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     01-07-2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     02-07-2010   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     06-07-2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2188  11-03-2019  283.519989  291.279999  280.500000  290.920013  290.920013
# 2189  12-03-2019  286.489990  288.070007  281.059998  283.359985  283.359985
# 2190  13-03-2019  283.899994  291.989990  282.700012  288.959991  288.959991
# 2191  14-03-2019  292.450012  295.390015  288.290009  289.959991  289.959991
# 2192  15-03-2019  283.510010  283.723999  274.399994  275.429993  275.429993
#
#         Volume
# 0     18766300
# ...

# %%
#Check number of Null values in each row (Check df.isnull().sum())
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
#Check basic info of df (Check df.info())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2193 non-null   object
#  1   Open       2193 non-null   float64
#  2   High       2193 non-null   float64
#  3   Low        2193 non-null   float64
#  4   Close      2193 non-null   float64
#  5   Adj Close  2193 non-null   float64
#  6   Volume     2193 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 120.1+ KB

# %%
#Check statistical info of df (check df.describe())
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2193.000000  2193.000000  2193.000000  2193.000000  2193.000000
# mean    175.652882   178.710262   172.412075   175.648555   175.648555
# std     115.580903   117.370092   113.654794   115.580771   115.580771
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      33.110001    33.910000    32.459999    33.160000    33.160000
# 50%     204.990005   208.160004   201.669998   204.990005   204.990005
# 75%     262.000000   265.329987   256.209991   261.739990   261.739990
# max     386.690002   389.609985   379.350006   385.000000   385.000000
#
#              Volume
# count  2.193000e+03
# mean   5.077449e+06
# std    4.545398e+06
# min    1.185000e+05
# 25%    1.577800e+06
# 50%    4.171700e+06
# 75%    6.885600e+06
# max    3.716390e+07

# %%
sns.pairplot(df,palette='rocket')

# %%
#changed the Dtype "object" to "datetime"
df2=pd.read_csv("/content/drive/MyDrive/Self Learning /tesla.csv")
df2
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     29-06-2010   19.000000   25.000000   17.540001   23.889999   23.889999
# 1     30-06-2010   25.790001   30.420000   23.299999   23.830000   23.830000
# 2     01-07-2010   25.000000   25.920000   20.270000   21.959999   21.959999
# 3     02-07-2010   23.000000   23.100000   18.709999   19.200001   19.200001
# 4     06-07-2010   20.000000   20.000000   15.830000   16.110001   16.110001
# ...          ...         ...         ...         ...         ...         ...
# 2188  11-03-2019  283.519989  291.279999  280.500000  290.920013  290.920013
# 2189  12-03-2019  286.489990  288.070007  281.059998  283.359985  283.359985
# 2190  13-03-2019  283.899994  291.989990  282.700012  288.959991  288.959991
# 2191  14-03-2019  292.450012  295.390015  288.290009  289.959991  289.959991
# 2192  15-03-2019  283.510010  283.723999  274.399994  275.429993  275.429993
#
#         Volume
# 0     18766300
# ...

# %%
df2["Date"] = pd.to_datetime(df2["Date"],format='%d-%m-%Y')
df2['Date']
# Out:
# 0      2010-06-29
# 1      2010-06-30
# 2      2010-07-01
# 3      2010-07-02
# 4      2010-07-06
#           ...
# 2188   2019-03-11
# 2189   2019-03-12
# 2190   2019-03-13
# 2191   2019-03-14
# 2192   2019-03-15
# Name: Date, Length: 2193, dtype: datetime64[ns]

# %%
df2.set_index('Date',inplace=True)

# %%
plt.figure(figsize=(12,4),dpi=300)
plt.plot(df2.Close)
plt.show()

# %%
sns.heatmap(df2.corr(),cbar=True,linewidth = 0.5)
#we can infer the correlation between different combination of veriable

# %%
#volume chart 
plt.figure(figsize=(12,4),dpi=300)
plt.bar(df2.index,df2["Volume"])
# Out:
# <BarContainer object of 2193 artists>

# %%
#@title Implementing Linear Regression Model

# %%
#Seperating Target and Feature veriable
x = df2.iloc[:,[0,1,2,5]].values
x
# Out:
# array([[1.90000000e+01, 2.50000000e+01, 1.75400010e+01, 1.87663000e+07],
#        [2.57900010e+01, 3.04200000e+01, 2.32999990e+01, 1.71871000e+07],
#        [2.50000000e+01, 2.59200000e+01, 2.02700000e+01, 8.21880000e+06],
#        ...,
#        [2.83899994e+02, 2.91989990e+02, 2.82700012e+02, 6.84470000e+06],
#        [2.92450012e+02, 2.95390015e+02, 2.88290009e+02, 7.07420000e+06],
#        [2.83510010e+02, 2.83723999e+02, 2.74399994e+02, 1.47582430e+07]])

# %%
y = df2["Close"]
y
# Out:
# Date
# 2010-06-29     23.889999
# 2010-06-30     23.830000
# 2010-07-01     21.959999
# 2010-07-02     19.200001
# 2010-07-06     16.110001
#                  ...
# 2019-03-11    290.920013
# 2019-03-12    283.359985
# 2019-03-13    288.959991
# 2019-03-14    289.959991
# 2019-03-15    275.429993
# Name: Close, Length: 2193, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(x_train)

# %%
print(scaler)
# Out:
# StandardScaler()

# %%
scaler.transform(x_train)
# Out:
# array([[-0.50625798, -0.49351756, -0.5103569 ,  1.55576705],
#        [-1.28915025, -1.29034942, -1.28568978, -0.9735316 ],
#        [-1.26435866, -1.26414517, -1.25695738, -0.97706051],
#        ...,
#        [-0.44858495, -0.45755097, -0.44979785,  0.5391515 ],
#        [-0.05174553, -0.01490463, -0.06292706,  1.40542203],
#        [ 0.60370932,  0.61117143,  0.63893926,  0.26822418]])

# %%
x_train_scaled = scaler.transform(x_train)

# %%
scaler = StandardScaler().fit(x_test)

# %%
scaler.transform(x_test)
# Out:
# array([[-1.22418409, -1.22161788, -1.21971905, -0.90733337],
#        [ 0.77118366,  0.75399532,  0.80587041, -0.31461006],
#        [ 0.95183258,  0.91336609,  0.90689898,  0.44353134],
#        ...,
#        [ 0.67411365,  0.65603029,  0.68477445, -0.36426105],
#        [-1.15799993, -1.15912444, -1.15354874, -0.6566076 ],
#        [-0.87247461, -0.79035446, -0.86412941,  4.24152303]])

# %%
x_test_scaled = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
regressor.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9997320963980917
